# %%
import numpy
import cv2
import matplotlib.pyplot as plt
import os

# %%
img = cv2.imread('dataset/kanye/original/ye.jpg')
plt.imshow(img)

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)


(x,y,w,h) = faces[0]

# %%
def get_cropped_img(path):
    img = cv2.imread(path,3)
    b,g,r = cv2.split(img)
    img = cv2.merge([r,g,b])
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    if len(faces)>0:
        (x,y,w,h) = faces[0]
        return img[y:y+h, x:x+w]

# %%
rappers = 'kanye drake jayz eminem nicki'.split()
for rapper in rappers:
    folder = os.listdir(f'dataset/{rapper}/original')
    if '.DS_Store' in folder:
        os.remove(os.path.join(f'dataset/{rapper}/original','.DS_Store'))
        print(f'removed ds store in {rapper}')

# %%
for rapper in rappers:
    for i, file in enumerate(os.listdir(f'dataset/{rapper}/original')):
        fullpath = os.path.join(f'dataset/{rapper}/original', file)
        cropped_image = get_cropped_img(fullpath)
        if isinstance(cropped_image, numpy.ndarray):
            number = str(i).zfill(2)
            plt.imsave(f'dataset/{rapper}/cropped/{number}.png',cropped_image)
            print(f'saved to dataset/{rapper}/cropped/{number}.png')
# Out:
# saved to dataset/kanye/cropped/00.png
# saved to dataset/kanye/cropped/01.png
# saved to dataset/kanye/cropped/02.png
# saved to dataset/kanye/cropped/03.png
# saved to dataset/kanye/cropped/04.png
# saved to dataset/kanye/cropped/06.png
# saved to dataset/kanye/cropped/08.png
# saved to dataset/kanye/cropped/09.png
# saved to dataset/kanye/cropped/10.png
# saved to dataset/kanye/cropped/12.png
# saved to dataset/kanye/cropped/13.png
# saved to dataset/kanye/cropped/14.png
# saved to dataset/kanye/cropped/15.png
# saved to dataset/kanye/cropped/16.png
# saved to dataset/kanye/cropped/19.png
# saved to dataset/kanye/cropped/23.png
# saved to dataset/kanye/cropped/25.png
# saved to dataset/kanye/cropped/26.png
# saved to dataset/kanye/cropped/27.png
# saved to dataset/kanye/cropped/28.png
# saved to dataset/kanye/cropped/29.png
# saved to dataset/kanye/cropped/30.png
# saved to dataset/kanye/cropped/33.png
# saved to dataset/kanye/cropped/34.png
# saved to dataset/kanye/cropped/36.png
# saved to dataset/kanye/cropped/38.png
# saved to dataset/kanye/cropped/41.png
# saved to dataset/kanye/cropped/42.png
# saved to dataset/kanye/cropped/44.png
# saved to dataset/kanye/cropped/45.png
# saved to dataset/kanye/cropped/47.png
# saved to dataset/kanye/cropped/48.png
# saved to dataset/kanye/cropped/49.png
# saved to dataset/kanye/cropped/51.png
# saved to dataset/kanye/cropped/52.png
# saved to dataset/kanye/cropped/53.png
# saved to dataset/kanye/cropped/54.png
# saved to dataset/kanye/cropped/55.png
# saved to dataset/kanye/cropped/57.png
# saved to dataset/kanye/cropped/59.png
# saved to dataset/kanye/cropped/61.png
# saved to dataset/kanye/cropped/62.png
# saved to dataset/kanye/cropped/63.png
# saved to dataset/kanye/cropped/64.png
# saved to dataset/kanye/cropped/66.png
# saved to dataset/kanye/cropped/70.png
# saved to dataset/kanye/cropped/73.png
# saved to dataset/kanye/cropped/74.png
# saved to dataset/kanye/cropped/76.png
# saved to dataset/kanye/cropped/77.png
# saved to dataset/kanye/cropped/78.png
# saved to dataset/kanye/cropped/82.png
# saved to dataset/kanye/cropped/83.png
# saved to dataset/kanye/cropped/86.png
# saved to dataset/kanye/cropped/87.png
# saved to dataset/kanye/cropped/88.png
# saved to dataset/kanye/cropped/89.png
# saved to dataset/kanye/cropped/90.png
# saved to dataset/kanye/cropped/92.png
# saved to dataset/kanye/cropped/93.png
# saved to dataset/kanye/cropped/94.png
# saved to dataset/kanye/cropped/95.png
# saved to dataset/kanye/cropped/97.png
# saved to dataset/kanye/cropped/98.png
# saved to dataset/kanye/cropped/100.png
# saved to dataset/kanye/cropped/101.png
